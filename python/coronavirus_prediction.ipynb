# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sb
import numpy as np
# Out:
# /home/felix/.local/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
predict = pd.read_csv('../data/predict/predict.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6d734a167354> in <module>
# ----> 1 predict = pd.read_csv('../data/predict/predict.csv')
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...

# %%
predict.columns

# %%
predict['time'] = pd.to_datetime(predict['time'])
predict['first_confirmed'] = pd.to_datetime(predict['first_confirmed'])

predict['days'] = ((predict['time'] - predict['first_confirmed'])/np.timedelta64(1, 'D')).astype(int)

data = predict.drop(columns=['countrycode','lat','lon','time','first_confirmed','id','health_index','population'])
#data['population'].
#data['population'] = data['population'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a9fb433e527c> in <module>
# ----> 1 predict['time'] = pd.to_datetime(predict['time'])
#       2 predict['first_confirmed'] = pd.to_datetime(predict['first_confirmed'])
#       3
#       4 predict['days'] = ((predict['time'] - predict['first_confirmed'])/np.timedelta64(1, 'D')).astype(int)
#       5
#
# NameError: name 'predict' is not defined

# %%
countries = data.country.unique()

# %%
data[(data.country == countries[0]) & (data.days >= 0)]
# Out:
#         country  confirmed  deaths  recovered  netinfected  days_outbreak  \
# 33  Afghanistan          1       0          0            1              0
# 34  Afghanistan          1       0          0            1              1
# 35  Afghanistan          1       0          0            1              2
# 36  Afghanistan          1       0          0            1              3
# 37  Afghanistan          1       0          0            1              4
# 38  Afghanistan          1       0          0            1              5
# 39  Afghanistan          1       0          0            1              6
# 40  Afghanistan          1       0          0            1              7
# 41  Afghanistan          1       0          0            1              8
# 42  Afghanistan          1       0          0            1              9
# 43  Afghanistan          1       0          0            1             10
# 44  Afghanistan          1       0          0            1             11
#
# ...

# %%
data[data.days >= 0].corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col1 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col2 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col3 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col4 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col5 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_968656f4_63b1_11ea_8ac6_0242f4aaab54row0_col6 {
#             background-color:  #73a9cf;
#             color:  #000000;
# ...

# %%
data =

# %%
for el in countries:
    x = data[(data.country == el) & (data.days >= 0)]
    if len(x) > 40:
        print(el)
        x.corr().style.background_gradient()
        plt.show()
# Out:
# Australia
# Canada
# France
# Hong Kong
# Japan
# Macau
# Mainland China
# Malaysia
# Nepal
# Singapore
# South Korea
# Taiwan
# Thailand
# US
# Vietnam

# %% [markdown]
# # China

# %%
china['days'] = ((pd.to_datetime(china.time) - pd.to_datetime('2020-01-22'))/np.timedelta64(1, 'D')).astype(int)
# Out:
# /home/felix/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sb.pairplot(china[['days','confirmed','deaths','recovered','netinfected','SP500','DAX30']])
# Out:
# /home/felix/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/felix/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
china_data = china[['days','confirmed','deaths','recovered','netinfected','SP500','DAX30']]

# %%
corr = china[['days','confirmed','deaths','recovered','netinfected','SP500','DAX30']].corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# %%
sb.heatmap(corr, mask = mask)

# %%
from sklearn.model_selection import train_test_split

# %%
china_data.head(25).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col5 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_82d1dbca_639c_11ea_8ac6_0242f4aaab54row0_col6 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
# ...

# %%
china_data = china_data.fillna(0)
X_train, y_train, X_test, y_test = train_test_split()

# %%
china_data[['days','confirmed']].plot(x='days',y='confirmed')

# %% [markdown]
# # Germany

# %%
germany = predict[predict.country == 'Germany']
germany.confirmed.plot()

# %%
germany
# Out:
#         id  country        time  confirmed  deaths  recovered  netinfected  \
# 1395  1396  Germany  2020-01-22          0       0          0            0
# 1396  1397  Germany  2020-01-23          0       0          0            0
# 1397  1398  Germany  2020-01-24          0       0          0            0
# 1398  1399  Germany  2020-01-25          0       0          0            0
# 1399  1400  Germany  2020-01-26          0       0          0            0
# 1400  1401  Germany  2020-01-27          1       0          0            1
# 1401  1402  Germany  2020-01-28          4       0          0            4
# 1402  1403  Germany  2020-01-29          4       0          0            4
# 1403  1404  Germany  2020-01-30          4       0          0            4
# 1404  1405  Germany  2020-01-31          5       0          0            5
# 1405  1406  Germany  2020-02-01          8       0          0            8
# ...

# %%
germany['days'] = ((pd.to_datetime(germany.time) - pd.to_datetime(germany['first_confirmed'].head(1).values[0]))/np.timedelta64(1, 'D')).astype(int)
# Out:
# /home/felix/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
germany_data = germany[['days','confirmed','deaths','recovered','netinfected','SP500','DAX30','searchindex']]

# %%
germany_data.corr()
# Out:
#                  days  confirmed  deaths  recovered  netinfected     SP500  \
# days         1.000000   0.571426     NaN   0.884943     0.535808 -0.632778
# confirmed    0.571426   1.000000     NaN   0.516445     0.998717 -0.623940
# deaths            NaN        NaN     NaN        NaN          NaN       NaN
# recovered    0.884943   0.516445     NaN   1.000000     0.472414 -0.694893
# netinfected  0.535808   0.998717     NaN   0.472414     1.000000 -0.604646
# SP500       -0.632778  -0.623940     NaN  -0.694893    -0.604646  1.000000
# DAX30       -0.641404  -0.728937     NaN  -0.695315    -0.712393  0.959095
# searchindex  0.665648   0.685436     NaN   0.736153     0.661954 -0.943718
#
#                 DAX30  searchindex
# days        -0.641404     0.665648
# confirmed   -0.728937     0.685436
# deaths            NaN          NaN
# recovered   -0.695315     0.736153
# netinfected -0.712393     0.661954
# SP500        0.959095    -0.943718
# DAX30        1.000000    -0.955317
# ...

# %%
italy_normalized = italy.confirmed.values/italy.confirmed.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-2276d63350ce> in <module>
# ----> 1 italy_normalized = italy.confirmed.values/italy.confirmed.max()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'confirmed'

# %%
italy_normalized
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.31406385e-04, 4.31406385e-04, 4.31406385e-04,
#        4.31406385e-04, 4.31406385e-04, 4.31406385e-04, 4.31406385e-04,
#        6.47109577e-04, 6.47109577e-04, 6.47109577e-04, 6.47109577e-04,
#        6.47109577e-04, 6.47109577e-04, 6.47109577e-04, 6.47109577e-04,
#        6.47109577e-04, 6.47109577e-04, 6.47109577e-04, 6.47109577e-04,
#        6.47109577e-04, 6.47109577e-04, 4.31406385e-03, 1.33735979e-02,
#        3.34339948e-02, 4.93960311e-02, 6.94564280e-02, 9.77135462e-02,
#        1.41285591e-01, 1.91544435e-01, 2.43313201e-01, 3.65401208e-01,
#        4.39171700e-01, 5.39689387e-01, 6.66307161e-01, 8.32182916e-01,
#        1.00000000e+00])

# %%
popt, pcov = curve_fit(scaled_sigmoid, np.arange(len(italy)), italy)

# %%
plt.plot(italy_normalized[20:])
plt.plot(np.arange(40), sigmoid(np.arange(40),*popt))

# %%
italy = predict[predict.country == 'Italy']
italy.confirmed.plot()

# %%
from sklearn.linear_model import LogisticRegression

# %%
china.since_st
# Out:
#         id         country        time  confirmed  deaths  recovered  \
# 2385  2386  Mainland China  2020-01-22        547      17         28
# 2386  2387  Mainland China  2020-01-23        639      18         30
# 2387  2388  Mainland China  2020-01-24        916      26         36
# 2388  2389  Mainland China  2020-01-25       1399      42         39
# 2389  2390  Mainland China  2020-01-26       2062      56         49
# 2390  2391  Mainland China  2020-01-27       2863      82         58
# 2391  2392  Mainland China  2020-01-28       5494     131        101
# 2392  2393  Mainland China  2020-01-29       6070     133        120
# 2393  2394  Mainland China  2020-01-30       8124     171        135
# 2394  2395  Mainland China  2020-01-31       9783     213        214
# 2395  2396  Mainland China  2020-02-01      11871     259        275
# 2396  2397  Mainland China  2020-02-02      16607     361        463
# 2397  2398  Mainland China  2020-02-03      19693     425        614
# ...
